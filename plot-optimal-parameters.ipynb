# %% [markdown]
# # 数据导入

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import random
from sympy import *
import math 
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

#计算regret的数据
optimal_sum_cost=np.loadtxt("./data/00_optimal_sum_cost_varying_D_c_kappa_normal_distribution_(70,5).txt")

#大值攻击
sum_cost_large_online_algorithm=np.loadtxt("./data/01_large_Byzantine_attack_sum_cost.txt")
sum_cost_large_IOS_online_algorithm=np.loadtxt("./data/02_IOS_optimal_parameters_large_Byzantine_attack_sum_cost.txt")
sum_cost_large_TM_online_algorithm=np.loadtxt("./data/03_TM_optimal_parameters_large_Byzantine_attack_sum_cost.txt")
sum_cost_large_SCC_online_algorithm=np.loadtxt("./data/04_SCC_optimal_parameters_large_Byzantine_attack_sum_cost.txt")

#小值攻击
sum_cost_small_online_algorithm=np.loadtxt("./data/01_small_Byzantine_attack_sum_cost.txt")
sum_cost_small_IOS_online_algorithm=np.loadtxt("./data/02_IOS_optimal_parameters_small_Byzantine_attack_sum_cost.txt")
sum_cost_small_TM_online_algorithm=np.loadtxt("./data/03_TM_optimal_parameters_small_Byzantine_attack_sum_cost.txt")
sum_cost_small_SCC_online_algorithm=np.loadtxt("./data/04_SCC_optimal_parameters_small_Byzantine_attack_sum_cost.txt")

#大值高斯攻击
sum_cost_large_Gaussian_online_algorithm=np.loadtxt("./data/01_large_Gaussian_Byzantine_attack_sum_cost.txt")
sum_cost_large_Gaussian_IOS_online_algorithm=np.loadtxt("./data/02_IOS_optimal_parameters_large_Gaussian_Byzantine_attack_sum_cost.txt")
sum_cost_large_Gaussian_TM_online_algorithm=np.loadtxt("./data/03_TM_optimal_parameters_large_Gaussian_Byzantine_attack_sum_cost.txt")
sum_cost_large_Gaussian_SCC_online_algorithm=np.loadtxt("./data/04_SCC_optimal_parameters_large_Gaussian_Byzantine_attack_sum_cost.txt")

#小值高斯攻击
sum_cost_small_Gaussian_online_algorithm=np.loadtxt("./data/01_small_Gaussian_Byzantine_attack_sum_cost.txt")
sum_cost_small_Gaussian_IOS_online_algorithm=np.loadtxt("./data/02_IOS_optimal_parameters_small_Gaussian_Byzantine_attack_sum_cost.txt")
sum_cost_small_Gaussian_TM_online_algorithm=np.loadtxt("./data/03_TM_optimal_parameters_small_Gaussian_Byzantine_attack_sum_cost.txt")
sum_cost_small_Gaussian_SCC_online_algorithm=np.loadtxt("./data/04_SCC_optimal_parameters_small_Gaussian_Byzantine_attack_sum_cost.txt")


#计算约束违反的数据
d_power_demand=np.loadtxt("./data/d_power_demand_normal_distribution_(70,5).txt")

#大值攻击
sum_thermal_wind_power_station_strategy_large_online_algorithm=np.loadtxt("./data/01_large_Byzantine_attack_sum_thermal_wind_power_station_strategy.txt")
sum_thermal_wind_power_station_strategy_large_IOS_online_algorithm=np.loadtxt("./data/02_IOS_optimal_parameters_large_Byzantine_attack_sum_thermal_wind_power_station_strategy.txt")
sum_thermal_wind_power_station_strategy_large_TM_online_algorithm=np.loadtxt("./data/03_TM_optimal_parameters_large_Byzantine_attack_sum_thermal_wind_power_station_strategy.txt")
sum_thermal_wind_power_station_strategy_large_SCC_online_algorithm=np.loadtxt("./data/04_SCC_optimal_parameters_large_Byzantine_attack_sum_thermal_wind_power_station_strategy.txt")

#小值攻击
sum_thermal_wind_power_station_strategy_small_online_algorithm=np.loadtxt("./data/01_small_Byzantine_attack_sum_thermal_wind_power_station_strategy.txt")
sum_thermal_wind_power_station_strategy_small_IOS_online_algorithm=np.loadtxt("./data/02_IOS_optimal_parameters_small_Byzantine_attack_sum_thermal_wind_power_station_strategy.txt")
sum_thermal_wind_power_station_strategy_small_TM_online_algorithm=np.loadtxt("./data/03_TM_optimal_parameters_small_Byzantine_attack_sum_thermal_wind_power_station_strategy.txt")
sum_thermal_wind_power_station_strategy_small_SCC_online_algorithm=np.loadtxt("./data/04_SCC_optimal_parameters_small_Byzantine_attack_sum_thermal_wind_power_station_strategy.txt")

#大值高斯攻击
sum_thermal_wind_power_station_strategy_large_Gaussian_online_algorithm=np.loadtxt("./data/01_large_Gaussian_Byzantine_attack_sum_thermal_wind_power_station_strategy.txt")
sum_thermal_wind_power_station_strategy_large_Gaussian_IOS_online_algorithm=np.loadtxt("./data/02_IOS_optimal_parameters_large_Gaussian_Byzantine_attack_sum_thermal_wind_power_station_strategy.txt")
sum_thermal_wind_power_station_strategy_large_Gaussian_TM_online_algorithm=np.loadtxt("./data/03_TM_optimal_parameters_large_Gaussian_Byzantine_attack_sum_thermal_wind_power_station_strategy.txt")
sum_thermal_wind_power_station_strategy_large_Gaussian_SCC_online_algorithm=np.loadtxt("./data/04_SCC_optimal_parameters_large_Gaussian_Byzantine_attack_sum_thermal_wind_power_station_strategy.txt")

#小值高斯攻击
sum_thermal_wind_power_station_strategy_small_Gaussian_online_algorithm=np.loadtxt("./data/01_small_Gaussian_Byzantine_attack_sum_thermal_wind_power_station_strategy.txt")
sum_thermal_wind_power_station_strategy_small_Gaussian_IOS_online_algorithm=np.loadtxt("./data/02_IOS_optimal_parameters_small_Gaussian_Byzantine_attack_sum_thermal_wind_power_station_strategy.txt")
sum_thermal_wind_power_station_strategy_small_Gaussian_TM_online_algorithm=np.loadtxt("./data/03_TM_optimal_parameters_small_Gaussian_Byzantine_attack_sum_thermal_wind_power_station_strategy.txt")
sum_thermal_wind_power_station_strategy_small_Gaussian_SCC_online_algorithm=np.loadtxt("./data/04_SCC_optimal_parameters_small_Gaussian_Byzantine_attack_sum_thermal_wind_power_station_strategy.txt")

# %% [raw]
# 计算dynamic_regret

# %%
#大值攻击
#平均聚合 无鲁棒
dynamic_regret_large_online_algorithm=[]
dynamic_regret_large_online_algorithm_log=[]
for T in range(1, 1000):
    dynamic_regret_auxiliary_variable_large_online_algorithm=0
    for t in range(0, T):
        dynamic_regret_auxiliary_variable_large_online_algorithm=dynamic_regret_auxiliary_variable_large_online_algorithm+sum_cost_large_online_algorithm[t+1]-optimal_sum_cost[t+1]
    dynamic_regret_large_online_algorithm.append(dynamic_regret_auxiliary_variable_large_online_algorithm)
    '''if dynamic_regret_auxiliary_variable_large_online_algorithm>0:
        dynamic_regret_large_online_algorithm_log.append(math.log(dynamic_regret_auxiliary_variable_large_online_algorithm,1.02))
    else:
        dynamic_regret_large_online_algorithm_log.append(-math.log(abs(dynamic_regret_auxiliary_variable_large_online_algorithm),1))'''
    
#IOS
dynamic_regret_large_IOS_online_algorithm=[]
dynamic_regret_large_IOS_online_algorithm_log=[]
for T in range(1, 1000):
    dynamic_regret_auxiliary_variable_large_IOS_online_algorithm=0
    for t in range(0, T):
        dynamic_regret_auxiliary_variable_large_IOS_online_algorithm=dynamic_regret_auxiliary_variable_large_IOS_online_algorithm+sum_cost_large_IOS_online_algorithm[t+1]-optimal_sum_cost[t+1]
    dynamic_regret_large_IOS_online_algorithm.append(dynamic_regret_auxiliary_variable_large_IOS_online_algorithm)
    '''if dynamic_regret_auxiliary_variable_large_IOS_online_algorithm>0:
        dynamic_regret_large_IOS_online_algorithm_log.append(math.log(dynamic_regret_auxiliary_variable_large_IOS_online_algorithm,1))
    else:
        dynamic_regret_large_IOS_online_algorithm_log.append(-math.log(abs(dynamic_regret_auxiliary_variable_large_IOS_online_algorithm),1))'''
#TM
dynamic_regret_large_TM_online_algorithm=[]
dynamic_regret_large_TM_online_algorithm_log=[]
for T in range(1, 1000):
    dynamic_regret_auxiliary_variable_large_TM_online_algorithm=0
    for t in range(0, T):
        dynamic_regret_auxiliary_variable_large_TM_online_algorithm=dynamic_regret_auxiliary_variable_large_TM_online_algorithm+sum_cost_large_TM_online_algorithm[t+1]-optimal_sum_cost[t+1]
    dynamic_regret_large_TM_online_algorithm.append(dynamic_regret_auxiliary_variable_large_TM_online_algorithm)
    '''if dynamic_regret_auxiliary_variable_large_TM_online_algorithm>0:
        dynamic_regret_large_TM_online_algorithm_log.append(math.log(dynamic_regret_auxiliary_variable_large_TM_online_algorithm,1))
    else:
        dynamic_regret_large_TM_online_algorithm_log.append(-math.log(abs(dynamic_regret_auxiliary_variable_large_TM_online_algorithm),1))'''
#SCC
dynamic_regret_large_SCC_online_algorithm=[]
dynamic_regret_large_SCC_online_algorithm_log=[]
for T in range(1, 1000):
    dynamic_regret_auxiliary_variable_large_SCC_online_algorithm=0
    for t in range(0, T):
        dynamic_regret_auxiliary_variable_large_SCC_online_algorithm=dynamic_regret_auxiliary_variable_large_SCC_online_algorithm+sum_cost_large_SCC_online_algorithm[t+1]-optimal_sum_cost[t+1]
    dynamic_regret_large_SCC_online_algorithm.append(dynamic_regret_auxiliary_variable_large_SCC_online_algorithm)
    '''if dynamic_regret_auxiliary_variable_large_SCC_online_algorithm>0:
        dynamic_regret_large_SCC_online_algorithm_log.append(math.log(dynamic_regret_auxiliary_variable_large_SCC_online_algorithm,1))
    else:
        dynamic_regret_large_SCC_online_algorithm_log.append(-math.log(abs(dynamic_regret_auxiliary_variable_large_SCC_online_algorithm),1))'''

# %%
#小值攻击
#平均聚合 无鲁棒
dynamic_regret_small_online_algorithm=[]
for T in range(1, 1000):
    dynamic_regret_auxiliary_variable_small_online_algorithm=0
    for t in range(0, T):
        dynamic_regret_auxiliary_variable_small_online_algorithm=dynamic_regret_auxiliary_variable_small_online_algorithm+sum_cost_small_online_algorithm[t+1]-optimal_sum_cost[t+1]
    dynamic_regret_small_online_algorithm.append(dynamic_regret_auxiliary_variable_small_online_algorithm)
#IOS
dynamic_regret_small_IOS_online_algorithm=[]
for T in range(1, 1000):
    dynamic_regret_auxiliary_variable_small_IOS_online_algorithm=0
    for t in range(0, T):
        dynamic_regret_auxiliary_variable_small_IOS_online_algorithm=dynamic_regret_auxiliary_variable_small_IOS_online_algorithm+sum_cost_small_IOS_online_algorithm[t+1]-optimal_sum_cost[t+1]
    dynamic_regret_small_IOS_online_algorithm.append(dynamic_regret_auxiliary_variable_small_IOS_online_algorithm)
#TM
dynamic_regret_small_TM_online_algorithm=[]
for T in range(1, 1000):
    dynamic_regret_auxiliary_variable_small_TM_online_algorithm=0
    for t in range(0, T):
        dynamic_regret_auxiliary_variable_small_TM_online_algorithm=dynamic_regret_auxiliary_variable_small_TM_online_algorithm+sum_cost_small_TM_online_algorithm[t+1]-optimal_sum_cost[t+1]
    dynamic_regret_small_TM_online_algorithm.append(dynamic_regret_auxiliary_variable_small_TM_online_algorithm)
#SCC
dynamic_regret_small_SCC_online_algorithm=[]
for T in range(1, 1000):
    dynamic_regret_auxiliary_variable_small_SCC_online_algorithm=0
    for t in range(0, T):
        dynamic_regret_auxiliary_variable_small_SCC_online_algorithm=dynamic_regret_auxiliary_variable_small_SCC_online_algorithm+sum_cost_small_SCC_online_algorithm[t+1]-optimal_sum_cost[t+1]
    dynamic_regret_small_SCC_online_algorithm.append(dynamic_regret_auxiliary_variable_small_SCC_online_algorithm)

# %%
#大值高斯攻击
#平均聚合 无鲁棒
dynamic_regret_large_Gaussian_online_algorithm=[]
for T in range(1, 1000):
    dynamic_regret_auxiliary_variable_large_Gaussian_online_algorithm=0
    for t in range(0, T):
        dynamic_regret_auxiliary_variable_large_Gaussian_online_algorithm=dynamic_regret_auxiliary_variable_large_Gaussian_online_algorithm+sum_cost_large_Gaussian_online_algorithm[t+1]-optimal_sum_cost[t+1]
    dynamic_regret_large_Gaussian_online_algorithm.append(dynamic_regret_auxiliary_variable_large_Gaussian_online_algorithm)
#IOS
dynamic_regret_large_Gaussian_IOS_online_algorithm=[]
for T in range(1, 1000):
    dynamic_regret_auxiliary_variable_large_Gaussian_IOS_online_algorithm=0
    for t in range(0, T):
        dynamic_regret_auxiliary_variable_large_Gaussian_IOS_online_algorithm=dynamic_regret_auxiliary_variable_large_Gaussian_IOS_online_algorithm+sum_cost_large_Gaussian_IOS_online_algorithm[t+1]-optimal_sum_cost[t+1]
    dynamic_regret_large_Gaussian_IOS_online_algorithm.append(dynamic_regret_auxiliary_variable_large_Gaussian_IOS_online_algorithm)
#TM
dynamic_regret_large_Gaussian_TM_online_algorithm=[]
for T in range(1, 1000):
    dynamic_regret_auxiliary_variable_large_Gaussian_TM_online_algorithm=0
    for t in range(0, T):
        dynamic_regret_auxiliary_variable_large_Gaussian_TM_online_algorithm=dynamic_regret_auxiliary_variable_large_Gaussian_TM_online_algorithm+sum_cost_large_Gaussian_TM_online_algorithm[t+1]-optimal_sum_cost[t+1]
    dynamic_regret_large_Gaussian_TM_online_algorithm.append(dynamic_regret_auxiliary_variable_large_Gaussian_TM_online_algorithm)
#SCC
dynamic_regret_large_Gaussian_SCC_online_algorithm=[]
for T in range(1, 1000):
    dynamic_regret_auxiliary_variable_large_Gaussian_SCC_online_algorithm=0
    for t in range(0, T):
        dynamic_regret_auxiliary_variable_large_Gaussian_SCC_online_algorithm=dynamic_regret_auxiliary_variable_large_Gaussian_SCC_online_algorithm+sum_cost_large_Gaussian_SCC_online_algorithm[t+1]-optimal_sum_cost[t+1]
    dynamic_regret_large_Gaussian_SCC_online_algorithm.append(dynamic_regret_auxiliary_variable_large_Gaussian_SCC_online_algorithm)

# %%
#小值高斯攻击
#平均聚合 无鲁棒
dynamic_regret_small_Gaussian_online_algorithm=[]
for T in range(1, 1000):
    dynamic_regret_auxiliary_variable_small_Gaussian_online_algorithm=0
    for t in range(0, T):
        dynamic_regret_auxiliary_variable_small_Gaussian_online_algorithm=dynamic_regret_auxiliary_variable_small_Gaussian_online_algorithm+sum_cost_small_Gaussian_online_algorithm[t+1]-optimal_sum_cost[t+1]
    dynamic_regret_small_Gaussian_online_algorithm.append(dynamic_regret_auxiliary_variable_small_Gaussian_online_algorithm)
#IOS
dynamic_regret_small_Gaussian_IOS_online_algorithm=[]
for T in range(1, 1000):
    dynamic_regret_auxiliary_variable_small_Gaussian_IOS_online_algorithm=0
    for t in range(0, T):
        dynamic_regret_auxiliary_variable_small_Gaussian_IOS_online_algorithm=dynamic_regret_auxiliary_variable_small_Gaussian_IOS_online_algorithm+sum_cost_small_Gaussian_IOS_online_algorithm[t+1]-optimal_sum_cost[t+1]
    dynamic_regret_small_Gaussian_IOS_online_algorithm.append(dynamic_regret_auxiliary_variable_small_Gaussian_IOS_online_algorithm)
#TM
dynamic_regret_small_Gaussian_TM_online_algorithm=[]
for T in range(1, 1000):
    dynamic_regret_auxiliary_variable_small_Gaussian_TM_online_algorithm=0
    for t in range(0, T):
        dynamic_regret_auxiliary_variable_small_Gaussian_TM_online_algorithm=dynamic_regret_auxiliary_variable_small_Gaussian_TM_online_algorithm+sum_cost_small_Gaussian_TM_online_algorithm[t+1]-optimal_sum_cost[t+1]
    dynamic_regret_small_Gaussian_TM_online_algorithm.append(dynamic_regret_auxiliary_variable_small_Gaussian_TM_online_algorithm)
#SCC
dynamic_regret_small_Gaussian_SCC_online_algorithm=[]
for T in range(1, 1000):
    dynamic_regret_auxiliary_variable_small_Gaussian_SCC_online_algorithm=0
    for t in range(0, T):
        dynamic_regret_auxiliary_variable_small_Gaussian_SCC_online_algorithm=dynamic_regret_auxiliary_variable_small_Gaussian_SCC_online_algorithm+sum_cost_small_Gaussian_SCC_online_algorithm[t+1]-optimal_sum_cost[t+1]
    dynamic_regret_small_Gaussian_SCC_online_algorithm.append(dynamic_regret_auxiliary_variable_small_Gaussian_SCC_online_algorithm)

# %% [raw]
# 计算约束违反累计

# %%
#大值攻击
#平均聚合 无鲁棒
accumulative_constraint_violation_large_online_algorithm=[]
for T in range(1, 1000):
    accumulative_constraint_violation_auxiliary_variable_large_online_algorithm=0
    for t in range(0, T): 
        accumulative_constraint_violation_auxiliary_variable_large_online_algorithm=accumulative_constraint_violation_auxiliary_variable_large_online_algorithm+(1/5)*sum_thermal_wind_power_station_strategy_large_online_algorithm[t+1]-d_power_demand[t+1]
    accumulative_constraint_violation_large_online_algorithm.append(abs(accumulative_constraint_violation_auxiliary_variable_large_online_algorithm))
#IOS
accumulative_constraint_violation_large_IOS_online_algorithm=[]
for T in range(1, 1000):
    accumulative_constraint_violation_auxiliary_variable_large_IOS_online_algorithm=0
    for t in range(0, T): 
        accumulative_constraint_violation_auxiliary_variable_large_IOS_online_algorithm=accumulative_constraint_violation_auxiliary_variable_large_IOS_online_algorithm+(1/5)*sum_thermal_wind_power_station_strategy_large_IOS_online_algorithm[t+1]-d_power_demand[t+1]
    accumulative_constraint_violation_large_IOS_online_algorithm.append(abs(accumulative_constraint_violation_auxiliary_variable_large_IOS_online_algorithm))    
#TM
accumulative_constraint_violation_large_TM_online_algorithm=[]
for T in range(1, 1000):
    accumulative_constraint_violation_auxiliary_variable_large_TM_online_algorithm=0
    for t in range(0, T): 
        accumulative_constraint_violation_auxiliary_variable_large_TM_online_algorithm=accumulative_constraint_violation_auxiliary_variable_large_TM_online_algorithm+(1/5)*sum_thermal_wind_power_station_strategy_large_TM_online_algorithm[t+1]-d_power_demand[t+1]
    accumulative_constraint_violation_large_TM_online_algorithm.append(abs(accumulative_constraint_violation_auxiliary_variable_large_TM_online_algorithm))    
#SCC
accumulative_constraint_violation_large_SCC_online_algorithm=[]
for T in range(1, 1000):
    accumulative_constraint_violation_auxiliary_variable_large_SCC_online_algorithm=0
    for t in range(0, T): 
        accumulative_constraint_violation_auxiliary_variable_large_SCC_online_algorithm=accumulative_constraint_violation_auxiliary_variable_large_SCC_online_algorithm+(1/5)*sum_thermal_wind_power_station_strategy_large_SCC_online_algorithm[t+1]-d_power_demand[t+1]
    accumulative_constraint_violation_large_SCC_online_algorithm.append(abs(accumulative_constraint_violation_auxiliary_variable_large_SCC_online_algorithm))

# %%
#小值攻击
#平均聚合 无鲁棒
accumulative_constraint_violation_small_online_algorithm=[]
for T in range(1, 1000):
    accumulative_constraint_violation_auxiliary_variable_small_online_algorithm=0
    for t in range(0, T): 
        accumulative_constraint_violation_auxiliary_variable_small_online_algorithm=accumulative_constraint_violation_auxiliary_variable_small_online_algorithm+(1/5)*sum_thermal_wind_power_station_strategy_small_online_algorithm[t+1]-d_power_demand[t+1]
    accumulative_constraint_violation_small_online_algorithm.append(abs(accumulative_constraint_violation_auxiliary_variable_small_online_algorithm))
#IOS
accumulative_constraint_violation_small_IOS_online_algorithm=[]
for T in range(1, 1000):
    accumulative_constraint_violation_auxiliary_variable_small_IOS_online_algorithm=0
    for t in range(0, T): 
        accumulative_constraint_violation_auxiliary_variable_small_IOS_online_algorithm=accumulative_constraint_violation_auxiliary_variable_small_IOS_online_algorithm+(1/5)*sum_thermal_wind_power_station_strategy_small_IOS_online_algorithm[t+1]-d_power_demand[t+1]
    accumulative_constraint_violation_small_IOS_online_algorithm.append(abs(accumulative_constraint_violation_auxiliary_variable_small_IOS_online_algorithm))    
#TM
accumulative_constraint_violation_small_TM_online_algorithm=[]
for T in range(1, 1000):
    accumulative_constraint_violation_auxiliary_variable_small_TM_online_algorithm=0
    for t in range(0, T): 
        accumulative_constraint_violation_auxiliary_variable_small_TM_online_algorithm=accumulative_constraint_violation_auxiliary_variable_small_TM_online_algorithm+(1/5)*sum_thermal_wind_power_station_strategy_small_TM_online_algorithm[t+1]-d_power_demand[t+1]
    accumulative_constraint_violation_small_TM_online_algorithm.append(abs(accumulative_constraint_violation_auxiliary_variable_small_TM_online_algorithm))    
#SCC
accumulative_constraint_violation_small_SCC_online_algorithm=[]
for T in range(1, 1000):
    accumulative_constraint_violation_auxiliary_variable_small_SCC_online_algorithm=0
    for t in range(0, T): 
        accumulative_constraint_violation_auxiliary_variable_small_SCC_online_algorithm=accumulative_constraint_violation_auxiliary_variable_small_SCC_online_algorithm+(1/5)*sum_thermal_wind_power_station_strategy_small_SCC_online_algorithm[t+1]-d_power_demand[t+1]
    accumulative_constraint_violation_small_SCC_online_algorithm.append(abs(accumulative_constraint_violation_auxiliary_variable_small_SCC_online_algorithm))

# %%
#大值高斯攻击
#平均聚合 无鲁棒
accumulative_constraint_violation_large_Gaussian_online_algorithm=[]
for T in range(1, 1000):
    accumulative_constraint_violation_auxiliary_variable_large_Gaussian_online_algorithm=0
    for t in range(0, T): 
        accumulative_constraint_violation_auxiliary_variable_large_Gaussian_online_algorithm=accumulative_constraint_violation_auxiliary_variable_large_Gaussian_online_algorithm+(1/5)*sum_thermal_wind_power_station_strategy_large_Gaussian_online_algorithm[t+1]-d_power_demand[t+1]
    accumulative_constraint_violation_large_Gaussian_online_algorithm.append(abs(accumulative_constraint_violation_auxiliary_variable_large_Gaussian_online_algorithm))
#IOS
accumulative_constraint_violation_large_Gaussian_IOS_online_algorithm=[]
for T in range(1, 1000):
    accumulative_constraint_violation_auxiliary_variable_large_Gaussian_IOS_online_algorithm=0
    for t in range(0, T): 
        accumulative_constraint_violation_auxiliary_variable_large_Gaussian_IOS_online_algorithm=accumulative_constraint_violation_auxiliary_variable_large_Gaussian_IOS_online_algorithm+(1/5)*sum_thermal_wind_power_station_strategy_large_Gaussian_IOS_online_algorithm[t+1]-d_power_demand[t+1]
    accumulative_constraint_violation_large_Gaussian_IOS_online_algorithm.append(abs(accumulative_constraint_violation_auxiliary_variable_large_Gaussian_IOS_online_algorithm))    
#TM
accumulative_constraint_violation_large_Gaussian_TM_online_algorithm=[]
for T in range(1, 1000):
    accumulative_constraint_violation_auxiliary_variable_large_Gaussian_TM_online_algorithm=0
    for t in range(0, T): 
        accumulative_constraint_violation_auxiliary_variable_large_Gaussian_TM_online_algorithm=accumulative_constraint_violation_auxiliary_variable_large_Gaussian_TM_online_algorithm+(1/5)*sum_thermal_wind_power_station_strategy_large_Gaussian_TM_online_algorithm[t+1]-d_power_demand[t+1]
    accumulative_constraint_violation_large_Gaussian_TM_online_algorithm.append(abs(accumulative_constraint_violation_auxiliary_variable_large_Gaussian_TM_online_algorithm))    
#SCC
accumulative_constraint_violation_large_Gaussian_SCC_online_algorithm=[]
for T in range(1, 1000):
    accumulative_constraint_violation_auxiliary_variable_large_Gaussian_SCC_online_algorithm=0
    for t in range(0, T): 
        accumulative_constraint_violation_auxiliary_variable_large_Gaussian_SCC_online_algorithm=accumulative_constraint_violation_auxiliary_variable_large_Gaussian_SCC_online_algorithm+(1/5)*sum_thermal_wind_power_station_strategy_large_Gaussian_SCC_online_algorithm[t+1]-d_power_demand[t+1]
    accumulative_constraint_violation_large_Gaussian_SCC_online_algorithm.append(abs(accumulative_constraint_violation_auxiliary_variable_large_Gaussian_SCC_online_algorithm))

# %%
#小值高斯攻击
#平均聚合 无鲁棒
accumulative_constraint_violation_small_Gaussian_online_algorithm=[]
for T in range(1, 1000):
    accumulative_constraint_violation_auxiliary_variable_small_Gaussian_online_algorithm=0
    for t in range(0, T): 
        accumulative_constraint_violation_auxiliary_variable_small_Gaussian_online_algorithm=accumulative_constraint_violation_auxiliary_variable_small_Gaussian_online_algorithm+(1/5)*sum_thermal_wind_power_station_strategy_small_Gaussian_online_algorithm[t+1]-d_power_demand[t+1]
    accumulative_constraint_violation_small_Gaussian_online_algorithm.append(abs(accumulative_constraint_violation_auxiliary_variable_small_Gaussian_online_algorithm))
#IOS
accumulative_constraint_violation_small_Gaussian_IOS_online_algorithm=[]
for T in range(1, 1000):
    accumulative_constraint_violation_auxiliary_variable_small_Gaussian_IOS_online_algorithm=0
    for t in range(0, T): 
        accumulative_constraint_violation_auxiliary_variable_small_Gaussian_IOS_online_algorithm=accumulative_constraint_violation_auxiliary_variable_small_Gaussian_IOS_online_algorithm+(1/5)*sum_thermal_wind_power_station_strategy_small_Gaussian_IOS_online_algorithm[t+1]-d_power_demand[t+1]
    accumulative_constraint_violation_small_Gaussian_IOS_online_algorithm.append(abs(accumulative_constraint_violation_auxiliary_variable_small_Gaussian_IOS_online_algorithm))    
#TM
accumulative_constraint_violation_small_Gaussian_TM_online_algorithm=[]
for T in range(1, 1000):
    accumulative_constraint_violation_auxiliary_variable_small_Gaussian_TM_online_algorithm=0
    for t in range(0, T): 
        accumulative_constraint_violation_auxiliary_variable_small_Gaussian_TM_online_algorithm=accumulative_constraint_violation_auxiliary_variable_small_Gaussian_TM_online_algorithm+(1/5)*sum_thermal_wind_power_station_strategy_small_Gaussian_TM_online_algorithm[t+1]-d_power_demand[t+1]
    accumulative_constraint_violation_small_Gaussian_TM_online_algorithm.append(abs(accumulative_constraint_violation_auxiliary_variable_small_Gaussian_TM_online_algorithm))    
#SCC
accumulative_constraint_violation_small_Gaussian_SCC_online_algorithm=[]
for T in range(1, 1000):
    accumulative_constraint_violation_auxiliary_variable_small_Gaussian_SCC_online_algorithm=0
    for t in range(0, T): 
        accumulative_constraint_violation_auxiliary_variable_small_Gaussian_SCC_online_algorithm=accumulative_constraint_violation_auxiliary_variable_small_Gaussian_SCC_online_algorithm+(1/5)*sum_thermal_wind_power_station_strategy_small_Gaussian_SCC_online_algorithm[t+1]-d_power_demand[t+1]
    accumulative_constraint_violation_small_Gaussian_SCC_online_algorithm.append(abs(accumulative_constraint_violation_auxiliary_variable_small_Gaussian_SCC_online_algorithm))

# %% [raw]
# 绘图 dynamic_regret

# %%
ax1=plt.subplot(1, 4, 1)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)
#大值攻击
#在同一幅图片上画4条折线

B=ax1.plot(iteration,dynamic_regret_large_IOS_online_algorithm,color = 'green',linewidth = '3',label='proposed+IOS')
C=ax1.plot(iteration,dynamic_regret_large_TM_online_algorithm,color = 'blue',linewidth = '3',label='proposed+TM')
D=ax1.plot(iteration,dynamic_regret_large_SCC_online_algorithm,color = 'red',linewidth = '3',label='proposed+SCC')

ax2 = ax1.twinx()

A=ax2.plot(iteration,dynamic_regret_large_online_algorithm,color = 'dimgrey',linewidth = '3',label='attack-free')
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=28)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 28,
}

ax1.set_xlabel('T', fontsize=28)
ax1.set_ylabel('Dynamic regret', fontsize=28)
#ax2.set_ylabel('Dynamic regret', fontsize=28)
plt.title('large-value',font2) 

# Combine legend labels and handles
lines =A+ B + C + D
labels = [line.get_label() for line in lines]

# Set scientific notation for both y-axes
ax1.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
ax2.ticklabel_format(axis='y', style='sci', scilimits=(0,0))


# Place 1e at the top of the axis
ax1.yaxis.get_offset_text().set_position((0, 1))
ax2.yaxis.get_offset_text().set_position((1, 1))

ax1.tick_params(axis='both', which='major', labelsize=22)
ax2.tick_params(axis='both', which='major', labelsize=22)

ax1.yaxis.offsetText.set_fontsize(22)  # 调整上标1e的大小
ax2.yaxis.offsetText.set_fontsize(22)  # 调整上标1e的大小

ax3=plt.subplot(1, 4, 2)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)    

B=ax3.plot(iteration,dynamic_regret_small_IOS_online_algorithm,color = 'green',linewidth = '3',label='proposed+IOS')
C=ax3.plot(iteration,dynamic_regret_small_TM_online_algorithm,color = 'blue',linewidth = '3',label='proposed+TM')
D=ax3.plot(iteration,dynamic_regret_small_SCC_online_algorithm,color = 'red',linewidth = '3',label='proposed+SCC')

ax4 = ax3.twinx()
A=ax4.plot(iteration,dynamic_regret_small_online_algorithm,color = 'dimgrey',linewidth = '3',label='attack-free')
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=28)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 28,
}
ax3.set_xlabel('T', fontsize=28)
#ax3.set_ylabel('Dynamic regret', fontsize=18)
#ax2.set_ylabel('Dynamic regret', fontsize=18)
plt.title('small-value',font2)

# Set scientific notation for both y-axes
ax3.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
ax4.ticklabel_format(axis='y', style='sci', scilimits=(0,0))

# Place 1e at the top of the axis
ax3.yaxis.get_offset_text().set_position((0, 1))
ax4.yaxis.get_offset_text().set_position((1, 1))

ax3.tick_params(axis='both', which='major', labelsize=22)
ax4.tick_params(axis='both', which='major', labelsize=22)

ax3.yaxis.offsetText.set_fontsize(22)  # 调整上标1e的大小
ax4.yaxis.offsetText.set_fontsize(22)  # 调整上标1e的大小

ax3.set_ylim(-25000, 500000)

ax5=plt.subplot(1, 4, 3)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

B=ax5.plot(iteration,dynamic_regret_large_Gaussian_IOS_online_algorithm,color = 'green',linewidth = '3',label='proposed+IOS')
C=ax5.plot(iteration,dynamic_regret_large_Gaussian_TM_online_algorithm,color = 'blue',linewidth = '3',label='proposed+TM')
D=ax5.plot(iteration,dynamic_regret_large_Gaussian_SCC_online_algorithm,color = 'red',linewidth = '3',label='proposed+SCC')

ax6 = ax5.twinx()
A=ax6.plot(iteration,dynamic_regret_large_Gaussian_online_algorithm,color = 'dimgrey',linewidth = '3',label='attack-free')

#设置图例并且设置图例的字体及大小
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=28)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 28,
}
ax5.set_xlabel('T', fontsize=28)
#ax3.set_ylabel('Dynamic regret', fontsize=18)
#ax2.set_ylabel('Dynamic regret', fontsize=18)
plt.title('large-value Gaussian',font2)

# Set scientific notation for both y-axes
ax5.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
ax6.ticklabel_format(axis='y', style='sci', scilimits=(0,0))

# Place 1e at the top of the axis
ax5.yaxis.get_offset_text().set_position((0, 1))
ax6.yaxis.get_offset_text().set_position((1, 1))

ax5.tick_params(axis='both', which='major', labelsize=22)
ax6.tick_params(axis='both', which='major', labelsize=22)

ax5.yaxis.offsetText.set_fontsize(22)  # 调整上标1e的大小
ax6.yaxis.offsetText.set_fontsize(22)  # 调整上标1e的大小

ax7=plt.subplot(1, 4, 4)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

B=ax7.plot(iteration,dynamic_regret_small_Gaussian_IOS_online_algorithm,color = 'green',linewidth = '3',label='proposed+IOS')
C=ax7.plot(iteration,dynamic_regret_small_Gaussian_TM_online_algorithm,color = 'blue',linewidth = '3',label='proposed+TM')
D=ax7.plot(iteration,dynamic_regret_small_Gaussian_SCC_online_algorithm,color = 'red',linewidth = '3',label='proposed+SCC')

ax8 = ax7.twinx()
A=ax8.plot(iteration,dynamic_regret_small_Gaussian_online_algorithm,color = 'dimgrey',linewidth = '3',label='attack-free')
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=28)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 28,
}
ax7.set_xlabel('T', fontsize=28)
#ax3.set_ylabel('Dynamic regret', fontsize=18)
#ax2.set_ylabel('Dynamic regret', fontsize=18)
plt.title('small-value Gaussian',font2)

# Set scientific notation for both y-axes
ax7.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
ax8.ticklabel_format(axis='y', style='sci', scilimits=(0,0))

# Place 1e at the top of the axis
ax7.yaxis.get_offset_text().set_position((0, 1))
ax8.yaxis.get_offset_text().set_position((1, 1))

ax7.tick_params(axis='both', which='major', labelsize=22)
ax8.tick_params(axis='both', which='major', labelsize=22)

ax7.yaxis.offsetText.set_fontsize(22)  # 调整上标1e的大小
ax8.yaxis.offsetText.set_fontsize(22)  # 调整上标1e的大小

ax7.set_ylim(-25000, 500000)

# Set legend for both axes
plt.legend(lines, labels, loc="upper center", bbox_to_anchor=[-1.3, -0.2], ncol=28, shadow=True, fancybox=True, prop={'size': 28})

plt.subplots_adjust(wspace=0.21,hspace=0.03) 
plt.gcf().set_size_inches((38, 8))

plt.savefig('./figures/01-figure1_dynamic_regret.pdf',format='pdf', bbox_inches='tight')
plt.savefig('./figures/01-figure1_dynamic_regret.png',format='png', bbox_inches='tight')

# %% [raw]
# 绘图 累计约束违反

# %%
ax1=plt.subplot(1, 4, 1)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)
#大值攻击
#在同一幅图片上画4条折线

B=ax1.plot(iteration,accumulative_constraint_violation_large_IOS_online_algorithm,color = 'green',linewidth = '3',label='proposed+IOS')
C=ax1.plot(iteration,accumulative_constraint_violation_large_TM_online_algorithm,color = 'blue',linewidth = '3',label='proposed+TM')
D=ax1.plot(iteration,accumulative_constraint_violation_large_SCC_online_algorithm,color = 'red',linewidth = '3',label='proposed+SCC')

ax2 = ax1.twinx()

A=ax2.plot(iteration,accumulative_constraint_violation_large_online_algorithm,color = 'dimgrey',linewidth = '3',label='attack-free')
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=28)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 28,
}

ax1.set_xlabel('T', fontsize=28)
ax1.set_ylabel('Accumulative constraint violations', fontsize=28)
#ax2.set_ylabel('Dynamic regret', fontsize=28)
plt.title('large-value',font2) 

# Combine legend labels and handles
lines =A+ B + C + D
labels = [line.get_label() for line in lines]

# Set scientific notation for both y-axes
ax1.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
ax2.ticklabel_format(axis='y', style='sci', scilimits=(0,0))


# Place 1e at the top of the axis
ax1.yaxis.get_offset_text().set_position((0, 1))
ax2.yaxis.get_offset_text().set_position((1, 1))

ax1.tick_params(axis='both', which='major', labelsize=22)
ax2.tick_params(axis='both', which='major', labelsize=22)

ax1.yaxis.offsetText.set_fontsize(22)  # 调整上标1e的大小
ax2.yaxis.offsetText.set_fontsize(22)  # 调整上标1e的大小

ax1.set_ylim(0, 6000)

ax3=plt.subplot(1, 4, 2)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)    

B=ax3.plot(iteration,accumulative_constraint_violation_small_IOS_online_algorithm,color = 'green',linewidth = '3',label='proposed+IOS')
C=ax3.plot(iteration,accumulative_constraint_violation_small_TM_online_algorithm,color = 'blue',linewidth = '3',label='proposed+TM')
D=ax3.plot(iteration,accumulative_constraint_violation_small_SCC_online_algorithm,color = 'red',linewidth = '3',label='proposed+SCC')

ax4 = ax3.twinx()
A=ax4.plot(iteration,accumulative_constraint_violation_small_online_algorithm,color = 'dimgrey',linewidth = '3',label='attack-free')
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=28)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 28,
}
ax3.set_xlabel('T', fontsize=28)
#ax3.set_ylabel('Dynamic regret', fontsize=18)
#ax2.set_ylabel('Dynamic regret', fontsize=18)
plt.title('small-value',font2)

# Set scientific notation for both y-axes
ax3.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
ax4.ticklabel_format(axis='y', style='sci', scilimits=(0,0))

# Place 1e at the top of the axis
ax3.yaxis.get_offset_text().set_position((0, 1))
ax4.yaxis.get_offset_text().set_position((1, 1))

ax3.tick_params(axis='both', which='major', labelsize=22)
ax4.tick_params(axis='both', which='major', labelsize=22)

ax3.yaxis.offsetText.set_fontsize(22)  # 调整上标1e的大小
ax4.yaxis.offsetText.set_fontsize(22)  # 调整上标1e的大小

ax3.set_ylim(0, 6000)

ax5=plt.subplot(1, 4, 3)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

B=ax5.plot(iteration,accumulative_constraint_violation_large_Gaussian_IOS_online_algorithm,color = 'green',linewidth = '3',label='proposed+IOS')
C=ax5.plot(iteration,accumulative_constraint_violation_large_Gaussian_TM_online_algorithm,color = 'blue',linewidth = '3',label='proposed+TM')
D=ax5.plot(iteration,accumulative_constraint_violation_large_Gaussian_SCC_online_algorithm,color = 'red',linewidth = '3',label='proposed+SCC')

ax6 = ax5.twinx()
A=ax6.plot(iteration,accumulative_constraint_violation_large_Gaussian_online_algorithm,color = 'dimgrey',linewidth = '3',label='attack-free')

#设置图例并且设置图例的字体及大小
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=28)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 28,
}
ax5.set_xlabel('T', fontsize=28)
#ax3.set_ylabel('Dynamic regret', fontsize=18)
#ax2.set_ylabel('Dynamic regret', fontsize=18)
plt.title('large-value Gaussian',font2)

# Set scientific notation for both y-axes
ax5.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
ax6.ticklabel_format(axis='y', style='sci', scilimits=(0,0))

# Place 1e at the top of the axis
ax5.yaxis.get_offset_text().set_position((0, 1))
ax6.yaxis.get_offset_text().set_position((1, 1))

ax5.tick_params(axis='both', which='major', labelsize=22)
ax6.tick_params(axis='both', which='major', labelsize=22)

ax5.yaxis.offsetText.set_fontsize(22)  # 调整上标1e的大小
ax6.yaxis.offsetText.set_fontsize(22)  # 调整上标1e的大小

ax5.set_ylim(0, 6000)

ax7=plt.subplot(1, 4, 4)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

B=ax7.plot(iteration,accumulative_constraint_violation_small_Gaussian_IOS_online_algorithm,color = 'green',linewidth = '3',label='proposed+IOS')
C=ax7.plot(iteration,accumulative_constraint_violation_small_Gaussian_TM_online_algorithm,color = 'blue',linewidth = '3',label='proposed+TM')
D=ax7.plot(iteration,accumulative_constraint_violation_small_Gaussian_SCC_online_algorithm,color = 'red',linewidth = '3',label='proposed+SCC')

ax8 = ax7.twinx()
A=ax8.plot(iteration,accumulative_constraint_violation_small_Gaussian_online_algorithm,color = 'dimgrey',linewidth = '3',label='attack-free')
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=28)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 28,
}
ax7.set_xlabel('T', fontsize=28)
#ax3.set_ylabel('Dynamic regret', fontsize=18)
#ax2.set_ylabel('Dynamic regret', fontsize=18)
plt.title('small-value Gaussian',font2)

# Set scientific notation for both y-axes
ax7.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
ax8.ticklabel_format(axis='y', style='sci', scilimits=(0,0))

# Place 1e at the top of the axis
ax7.yaxis.get_offset_text().set_position((0, 1))
ax8.yaxis.get_offset_text().set_position((1, 1))

ax7.tick_params(axis='both', which='major', labelsize=22)
ax8.tick_params(axis='both', which='major', labelsize=22)

ax7.yaxis.offsetText.set_fontsize(22)  # 调整上标1e的大小
ax8.yaxis.offsetText.set_fontsize(22)  # 调整上标1e的大小

ax7.set_ylim(0, 6000)

# Set legend for both axes
plt.legend(lines, labels, loc="upper center", bbox_to_anchor=[-1.3, -0.2], ncol=28, shadow=True, fancybox=True, prop={'size': 28})

plt.subplots_adjust(wspace=0.21,hspace=0.03) 
plt.gcf().set_size_inches((38, 8))

plt.savefig('./figures/02-figure2_accumulative_constraint_violation.pdf',format='pdf', bbox_inches='tight')
plt.savefig('./figures/02-figure2_accumulative_constraint_violation.png',format='png', bbox_inches='tight')

# %%
from matplotlib.ticker import StrMethodFormatter

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

# %%
ax1=plt.subplot(2, 4, 1)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)
#大值攻击
#在同一幅图片上画4条折线

B=ax1.plot(iteration,dynamic_regret_large_IOS_online_algorithm,color = 'green',linewidth = '3',label='proposed+IOS')
C=ax1.plot(iteration,dynamic_regret_large_TM_online_algorithm,color = 'blue',linewidth = '3',label='proposed+TM')
D=ax1.plot(iteration,dynamic_regret_large_SCC_online_algorithm,color = 'red',linewidth = '3',label='proposed+SCC')

ax2 = ax1.twinx()

A=ax2.plot(iteration,dynamic_regret_large_online_algorithm,color = 'dimgrey',linewidth = '3',label='attack-free')
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=28)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 28,
}

#ax1.set_xlabel('T', fontsize=28)
ax1.set_ylabel('Dynamic regret', fontsize=28)
#ax2.set_ylabel('Dynamic regret', fontsize=28)
plt.title('large-value',font2) 

# Combine legend labels and handles
lines =A+ B + C + D
labels = [line.get_label() for line in lines]

# Set scientific notation for both y-axes
ax1.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
ax2.ticklabel_format(axis='y', style='sci', scilimits=(0,0))


# Place 1e at the top of the axis
ax1.yaxis.get_offset_text().set_position((0, 1))
ax2.yaxis.get_offset_text().set_position((1, 1))

ax1.tick_params(axis='both', which='major', labelsize=22)
ax2.tick_params(axis='both', which='major', labelsize=22)

ax1.yaxis.offsetText.set_fontsize(22)  # 调整上标1e的大小
ax2.yaxis.offsetText.set_fontsize(22)  # 调整上标1e的大小

#ax2.set_yticklabels([ '-1.40', '-1.20', '-1.00', '-0.80','-0.60', '-0.40', '-0.20', '0.00'])  # 设置刻度值对应的显示标签

ax3=plt.subplot(2, 4, 2)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)    

B=ax3.plot(iteration,dynamic_regret_small_IOS_online_algorithm,color = 'green',linewidth = '3',label='proposed+IOS')
C=ax3.plot(iteration,dynamic_regret_small_TM_online_algorithm,color = 'blue',linewidth = '3',label='proposed+TM')
D=ax3.plot(iteration,dynamic_regret_small_SCC_online_algorithm,color = 'red',linewidth = '3',label='proposed+SCC')

ax4 = ax3.twinx()
A=ax4.plot(iteration,dynamic_regret_small_online_algorithm,color = 'dimgrey',linewidth = '3',label='attack-free')
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=28)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 28,
}
#ax3.set_xlabel('T', fontsize=28)
#ax3.set_ylabel('Dynamic regret', fontsize=18)
#ax2.set_ylabel('Dynamic regret', fontsize=18)
plt.title('small-value',font2)

# Set scientific notation for both y-axes
ax3.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
ax4.ticklabel_format(axis='y', style='sci', scilimits=(0,0))

# Place 1e at the top of the axis
ax3.yaxis.get_offset_text().set_position((0, 1))
ax4.yaxis.get_offset_text().set_position((1, 1))

ax3.tick_params(axis='both', which='major', labelsize=22)
ax4.tick_params(axis='both', which='major', labelsize=22)

ax3.yaxis.offsetText.set_fontsize(22)  # 调整上标1e的大小
ax4.yaxis.offsetText.set_fontsize(22)  # 调整上标1e的大小

ax3.set_ylim(-25000, 500000)

#ax3.yaxis.set_major_locator(MaxNLocator(nbins=8))

#ax3.set_yticklabels(['-1.00', '0.00', '1.00', '2.00', '3.00','4.00', '5.00'])  # 设置刻度值对应的显示标签
#ax4.set_yticklabels(['-1.00', '0.00', '1.00', '2.00', '3.00','4.00', '5.00'])  # 设置刻度值对应的显示标签

ax5=plt.subplot(2, 4, 3)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

B=ax5.plot(iteration,dynamic_regret_large_Gaussian_IOS_online_algorithm,color = 'green',linewidth = '3',label='proposed+IOS')
C=ax5.plot(iteration,dynamic_regret_large_Gaussian_TM_online_algorithm,color = 'blue',linewidth = '3',label='proposed+TM')
D=ax5.plot(iteration,dynamic_regret_large_Gaussian_SCC_online_algorithm,color = 'red',linewidth = '3',label='proposed+SCC')

ax6 = ax5.twinx()
A=ax6.plot(iteration,dynamic_regret_large_Gaussian_online_algorithm,color = 'dimgrey',linewidth = '3',label='attack-free')

#设置图例并且设置图例的字体及大小
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=28)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 28,
}
#ax5.set_xlabel('T', fontsize=28)
#ax3.set_ylabel('Dynamic regret', fontsize=18)
#ax2.set_ylabel('Dynamic regret', fontsize=18)
plt.title('large-value Gaussian',font2)

# Set scientific notation for both y-axes
ax5.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
ax6.ticklabel_format(axis='y', style='sci', scilimits=(0,0))

# Place 1e at the top of the axis
ax5.yaxis.get_offset_text().set_position((0, 1))
ax6.yaxis.get_offset_text().set_position((1, 1))

ax5.tick_params(axis='both', which='major', labelsize=22)
ax6.tick_params(axis='both', which='major', labelsize=22)

ax5.yaxis.offsetText.set_fontsize(22)  # 调整上标1e的大小
ax6.yaxis.offsetText.set_fontsize(22)  # 调整上标1e的大小

ax7=plt.subplot(2, 4, 4)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

B=ax7.plot(iteration,dynamic_regret_small_Gaussian_IOS_online_algorithm,color = 'green',linewidth = '3',label='proposed+IOS')
C=ax7.plot(iteration,dynamic_regret_small_Gaussian_TM_online_algorithm,color = 'blue',linewidth = '3',label='proposed+TM')
D=ax7.plot(iteration,dynamic_regret_small_Gaussian_SCC_online_algorithm,color = 'red',linewidth = '3',label='proposed+SCC')

ax8 = ax7.twinx()
A=ax8.plot(iteration,dynamic_regret_small_Gaussian_online_algorithm,color = 'dimgrey',linewidth = '3',label='attack-free')
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=28)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 28,
}
#ax7.set_xlabel('T', fontsize=28)
#ax3.set_ylabel('Dynamic regret', fontsize=18)
#ax2.set_ylabel('Dynamic regret', fontsize=18)
plt.title('small-value Gaussian',font2)

# Set scientific notation for both y-axes
ax7.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
ax8.ticklabel_format(axis='y', style='sci', scilimits=(0,0))

# Place 1e at the top of the axis
ax7.yaxis.get_offset_text().set_position((0, 1))
ax8.yaxis.get_offset_text().set_position((1, 1))

ax7.tick_params(axis='both', which='major', labelsize=22)
ax8.tick_params(axis='both', which='major', labelsize=22)

ax7.yaxis.offsetText.set_fontsize(22)  # 调整上标1e的大小
ax8.yaxis.offsetText.set_fontsize(22)  # 调整上标1e的大小

ax7.set_ylim(-25000, 500000)

ax9=plt.subplot(2, 4, 5)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)
#大值攻击
#在同一幅图片上画4条折线

B=ax9.plot(iteration,accumulative_constraint_violation_large_IOS_online_algorithm,color = 'green',linewidth = '3',label='proposed+IOS')
C=ax9.plot(iteration,accumulative_constraint_violation_large_TM_online_algorithm,color = 'blue',linewidth = '3',label='proposed+TM')
D=ax9.plot(iteration,accumulative_constraint_violation_large_SCC_online_algorithm,color = 'red',linewidth = '3',label='proposed+SCC')

ax10 = ax9.twinx()

A=ax10.plot(iteration,accumulative_constraint_violation_large_online_algorithm,color = 'dimgrey',linewidth = '3',label='attack-free')
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=28)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 28,
}

ax9.set_xlabel('T', fontsize=28)
ax9.set_ylabel('Accumulative constraint violations', fontsize=28)
#ax2.set_ylabel('Dynamic regret', fontsize=28)
#plt.title('large-value',font2) 

# Combine legend labels and handles
lines =A+ B + C + D
labels = [line.get_label() for line in lines]

# Set scientific notation for both y-axes
ax9.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
ax10.ticklabel_format(axis='y', style='sci', scilimits=(0,0))


# Place 1e at the top of the axis
ax9.yaxis.get_offset_text().set_position((0, 1))
ax10.yaxis.get_offset_text().set_position((1, 1))

ax9.tick_params(axis='both', which='major', labelsize=22)
ax10.tick_params(axis='both', which='major', labelsize=22)

ax9.yaxis.offsetText.set_fontsize(22)  # 调整上标1e的大小
ax10.yaxis.offsetText.set_fontsize(22)  # 调整上标1e的大小

ax9.set_ylim(0, 6000)

ax11=plt.subplot(2, 4, 6)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)    

B=ax11.plot(iteration,accumulative_constraint_violation_small_IOS_online_algorithm,color = 'green',linewidth = '3',label='proposed+IOS')
C=ax11.plot(iteration,accumulative_constraint_violation_small_TM_online_algorithm,color = 'blue',linewidth = '3',label='proposed+TM')
D=ax11.plot(iteration,accumulative_constraint_violation_small_SCC_online_algorithm,color = 'red',linewidth = '3',label='proposed+SCC')

ax12 = ax11.twinx()
A=ax12.plot(iteration,accumulative_constraint_violation_small_online_algorithm,color = 'dimgrey',linewidth = '3',label='attack-free')
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=28)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 28,
}
ax11.set_xlabel('T', fontsize=28)
#ax3.set_ylabel('Dynamic regret', fontsize=18)
#ax2.set_ylabel('Dynamic regret', fontsize=18)
#plt.title('small-value',font2)

# Set scientific notation for both y-axes
ax11.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
ax12.ticklabel_format(axis='y', style='sci', scilimits=(0,0))

# Place 1e at the top of the axis
ax11.yaxis.get_offset_text().set_position((0, 1))
ax12.yaxis.get_offset_text().set_position((1, 1))

ax11.tick_params(axis='both', which='major', labelsize=22)
ax12.tick_params(axis='both', which='major', labelsize=22)

ax11.yaxis.offsetText.set_fontsize(22)  # 调整上标1e的大小
ax12.yaxis.offsetText.set_fontsize(22)  # 调整上标1e的大小

ax11.set_ylim(0, 6000)

ax13=plt.subplot(2, 4, 7)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

B=ax13.plot(iteration,accumulative_constraint_violation_large_Gaussian_IOS_online_algorithm,color = 'green',linewidth = '3',label='proposed+IOS')
C=ax13.plot(iteration,accumulative_constraint_violation_large_Gaussian_TM_online_algorithm,color = 'blue',linewidth = '3',label='proposed+TM')
D=ax13.plot(iteration,accumulative_constraint_violation_large_Gaussian_SCC_online_algorithm,color = 'red',linewidth = '3',label='proposed+SCC')

ax14 = ax13.twinx()
A=ax14.plot(iteration,accumulative_constraint_violation_large_Gaussian_online_algorithm,color = 'dimgrey',linewidth = '3',label='attack-free')

#设置图例并且设置图例的字体及大小
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=28)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 28,
}
ax13.set_xlabel('T', fontsize=28)
#ax3.set_ylabel('Dynamic regret', fontsize=18)
#ax2.set_ylabel('Dynamic regret', fontsize=18)
#plt.title('large-value Gaussian',font2)

# Set scientific notation for both y-axes
ax13.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
ax14.ticklabel_format(axis='y', style='sci', scilimits=(0,0))

# Place 1e at the top of the axis
ax13.yaxis.get_offset_text().set_position((0, 1))
ax14.yaxis.get_offset_text().set_position((1, 1))

ax13.tick_params(axis='both', which='major', labelsize=22)
ax14.tick_params(axis='both', which='major', labelsize=22)

ax13.yaxis.offsetText.set_fontsize(22)  # 调整上标1e的大小
ax14.yaxis.offsetText.set_fontsize(22)  # 调整上标1e的大小

ax13.set_ylim(0, 6000)

ax15=plt.subplot(2, 4, 8)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

B=ax15.plot(iteration,accumulative_constraint_violation_small_Gaussian_IOS_online_algorithm,color = 'green',linewidth = '3',label='proposed+IOS')
C=ax15.plot(iteration,accumulative_constraint_violation_small_Gaussian_TM_online_algorithm,color = 'blue',linewidth = '3',label='proposed+TM')
D=ax15.plot(iteration,accumulative_constraint_violation_small_Gaussian_SCC_online_algorithm,color = 'red',linewidth = '3',label='proposed+SCC')

ax16 = ax15.twinx()
A=ax16.plot(iteration,accumulative_constraint_violation_small_Gaussian_online_algorithm,color = 'dimgrey',linewidth = '3',label='attack-free')
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=28)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 28,
}
ax15.set_xlabel('T', fontsize=28)
#ax3.set_ylabel('Dynamic regret', fontsize=18)
#ax2.set_ylabel('Dynamic regret', fontsize=18)
#plt.title('small-value Gaussian',font2)

# Set scientific notation for both y-axes
ax15.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
ax16.ticklabel_format(axis='y', style='sci', scilimits=(0,0))

# Place 1e at the top of the axis
ax15.yaxis.get_offset_text().set_position((0, 1))
ax16.yaxis.get_offset_text().set_position((1, 1))

ax15.tick_params(axis='both', which='major', labelsize=22)
ax16.tick_params(axis='both', which='major', labelsize=22)

ax15.yaxis.offsetText.set_fontsize(22)  # 调整上标1e的大小
ax16.yaxis.offsetText.set_fontsize(22)  # 调整上标1e的大小

ax15.set_ylim(0, 6000)

ax1.set_xticklabels([])
ax3.set_xticklabels([])
ax5.set_xticklabels([])
ax7.set_xticklabels([])

# Set legend for both axes
plt.legend(lines, labels, loc="upper center", bbox_to_anchor=[-1.3, -0.2], ncol=28, shadow=True, fancybox=True, prop={'size': 38})

plt.subplots_adjust(wspace=0.3,hspace=0.08) 
plt.gcf().set_size_inches((38, 16))

#plt.savefig('./figures/01-figure1_dynamic_regret.pdf',format='pdf', bbox_inches='tight')
#plt.savefig('./figures/01-figure1_dynamic_regret.png',format='png', bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as ticker

# %%
ax1=plt.subplot(2, 4, 1)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)
#大值攻击
#在同一幅图片上画4条折线

B=ax1.plot(iteration,dynamic_regret_large_IOS_online_algorithm,color = 'green',linewidth = '3',label='proposed+IOS')
C=ax1.plot(iteration,dynamic_regret_large_TM_online_algorithm,color = 'blue',linewidth = '3',label='proposed+TM')
D=ax1.plot(iteration,dynamic_regret_large_SCC_online_algorithm,color = 'red',linewidth = '3',label='proposed+SCC')

ax2 = ax1.twinx()

A=ax2.plot(iteration,dynamic_regret_large_online_algorithm,color = 'dimgrey',linewidth = '3',label='attack-free')
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=36)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 36,
}

#ax1.set_xlabel('T', fontsize=28)
ax1.set_ylabel(r'$R^{T}_{\mathcal{H}}$', fontsize=49)
#ax2.set_ylabel('Dynamic regret', fontsize=28)
#plt.title('large-value',font2) 

# Combine legend labels and handles
lines =A+ B + C + D
labels = [line.get_label() for line in lines]

# Set scientific notation for both y-axes
ax1.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
ax2.ticklabel_format(axis='y', style='sci', scilimits=(0,0))

# 设置自定义刻度间隔
interval = 0.5*1e6  # 设置刻度间隔为10^2
ax2.yaxis.set_major_locator(ticker.MultipleLocator(interval))

# Place 1e at the top of the axis
ax1.yaxis.get_offset_text().set_position((0, 1))
ax2.yaxis.get_offset_text().set_position((1, 1))

ax1.tick_params(axis='both', which='major', labelsize=36)
ax2.tick_params(axis='both', which='major', labelsize=36)

ax1.yaxis.offsetText.set_fontsize(36)  # 调整上标1e的大小
ax2.yaxis.offsetText.set_fontsize(36)  # 调整上标1e的大小

#ax2.set_yticklabels([ ' ', '-1.0', ' ', '-0.5',' ', '0.0'])  # 设置刻度值对应的显示标签

#ax2.set_yticklabels([ '-1.40', '-1.20', '-1.00', '-0.80','-0.60', '-0.40', '-0.20', '0.00'])  # 设置刻度值对应的显示标签

ax3=plt.subplot(2, 4, 2)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)    

B=ax3.plot(iteration,dynamic_regret_small_IOS_online_algorithm,color = 'green',linewidth = '3',label='proposed+IOS')
C=ax3.plot(iteration,dynamic_regret_small_TM_online_algorithm,color = 'blue',linewidth = '3',label='proposed+TM')
D=ax3.plot(iteration,dynamic_regret_small_SCC_online_algorithm,color = 'red',linewidth = '3',label='proposed+SCC')

ax4 = ax3.twinx()
A=ax4.plot(iteration,dynamic_regret_small_online_algorithm,color = 'dimgrey',linewidth = '3',label='attack-free')
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=36)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 36,
}
#ax3.set_xlabel('T', fontsize=28)
#ax3.set_ylabel('Dynamic regret', fontsize=18)
#ax2.set_ylabel('Dynamic regret', fontsize=18)
#plt.title('small-value',font2)

# Set scientific notation for both y-axes
ax3.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
ax4.ticklabel_format(axis='y', style='sci', scilimits=(0,0))

# Place 1e at the top of the axis
ax3.yaxis.get_offset_text().set_position((0, 1))
ax4.yaxis.get_offset_text().set_position((1, 1))

ax3.tick_params(axis='both', which='major', labelsize=36)
ax4.tick_params(axis='both', which='major', labelsize=36)

ax3.yaxis.offsetText.set_fontsize(36)  # 调整上标1e的大小
ax4.yaxis.offsetText.set_fontsize(36)  # 调整上标1e的大小

ax3.set_ylim(-25000, 500000)

#ax3.yaxis.set_major_locator(MaxNLocator(nbins=8))

#ax3.set_yticklabels(['-1.00', '0.00', '1.00', '2.00', '3.00','4.00', '5.00'])  # 设置刻度值对应的显示标签
#ax4.set_yticklabels(['-1.00', '0.00', '1.00', '2.00', '3.00','4.00', '5.00'])  # 设置刻度值对应的显示标签

ax5=plt.subplot(2, 4, 3)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

B=ax5.plot(iteration,dynamic_regret_large_Gaussian_IOS_online_algorithm,color = 'green',linewidth = '3',label='proposed+IOS')
C=ax5.plot(iteration,dynamic_regret_large_Gaussian_TM_online_algorithm,color = 'blue',linewidth = '3',label='proposed+TM')
D=ax5.plot(iteration,dynamic_regret_large_Gaussian_SCC_online_algorithm,color = 'red',linewidth = '3',label='proposed+SCC')

ax6 = ax5.twinx()
A=ax6.plot(iteration,dynamic_regret_large_Gaussian_online_algorithm,color = 'dimgrey',linewidth = '3',label='attack-free')

#设置图例并且设置图例的字体及大小
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=36)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 36,
}
#ax5.set_xlabel('T', fontsize=28)
#ax3.set_ylabel('Dynamic regret', fontsize=18)
#ax2.set_ylabel('Dynamic regret', fontsize=18)
#plt.title('large-value Gaussian',font2)

# Set scientific notation for both y-axes
ax5.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
ax6.ticklabel_format(axis='y', style='sci', scilimits=(0,0))

# 设置自定义刻度间隔
interval = 0.5*1e6  # 设置刻度间隔为10^2
ax6.yaxis.set_major_locator(ticker.MultipleLocator(interval))

# Place 1e at the top of the axis
ax5.yaxis.get_offset_text().set_position((0, 1))
ax6.yaxis.get_offset_text().set_position((1, 1))

ax5.tick_params(axis='both', which='major', labelsize=36)
ax6.tick_params(axis='both', which='major', labelsize=36)

ax5.yaxis.offsetText.set_fontsize(36)  # 调整上标1e的大小
ax6.yaxis.offsetText.set_fontsize(36)  # 调整上标1e的大小

ax7=plt.subplot(2, 4, 4)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

B=ax7.plot(iteration,dynamic_regret_small_Gaussian_IOS_online_algorithm,color = 'green',linewidth = '3',label='proposed+IOS')
C=ax7.plot(iteration,dynamic_regret_small_Gaussian_TM_online_algorithm,color = 'blue',linewidth = '3',label='proposed+TM')
D=ax7.plot(iteration,dynamic_regret_small_Gaussian_SCC_online_algorithm,color = 'red',linewidth = '3',label='proposed+SCC')

ax8 = ax7.twinx()
A=ax8.plot(iteration,dynamic_regret_small_Gaussian_online_algorithm,color = 'dimgrey',linewidth = '3',label='attack-free')
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=36)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 36,
}
#ax7.set_xlabel('T', fontsize=28)
#ax3.set_ylabel('Dynamic regret', fontsize=18)
#ax2.set_ylabel('Dynamic regret', fontsize=18)
#plt.title('small-value Gaussian',font2)

# Set scientific notation for both y-axes
ax7.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
ax8.ticklabel_format(axis='y', style='sci', scilimits=(0,0))

# Place 1e at the top of the axis
ax7.yaxis.get_offset_text().set_position((0, 1))
ax8.yaxis.get_offset_text().set_position((1, 1))

ax7.tick_params(axis='both', which='major', labelsize=36)
ax8.tick_params(axis='both', which='major', labelsize=36)

ax7.yaxis.offsetText.set_fontsize(36)  # 调整上标1e的大小
ax8.yaxis.offsetText.set_fontsize(36)  # 调整上标1e的大小

ax7.set_ylim(-25000, 500000)

ax9=plt.subplot(2, 4, 5)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)
#大值攻击
#在同一幅图片上画4条折线

B=ax9.plot(iteration,accumulative_constraint_violation_large_IOS_online_algorithm,color = 'green',linewidth = '3',label='proposed+IOS')
C=ax9.plot(iteration,accumulative_constraint_violation_large_TM_online_algorithm,color = 'blue',linewidth = '3',label='proposed+TM')
D=ax9.plot(iteration,accumulative_constraint_violation_large_SCC_online_algorithm,color = 'red',linewidth = '3',label='proposed+SCC')

ax10 = ax9.twinx()

A=ax10.plot(iteration,accumulative_constraint_violation_large_online_algorithm,color = 'dimgrey',linewidth = '3',label='attack-free')
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=36)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 36,
}

ax9.set_xlabel('T', fontsize=49)
ax9.set_ylabel(r'$V^{T}_{\mathcal{H}}$', fontsize=49, labelpad=25)
#ax2.set_ylabel('Dynamic regret', fontsize=28)
#plt.title('large-value',font2) 

# Combine legend labels and handles
lines =A+ B + C + D
labels = [line.get_label() for line in lines]

# Set scientific notation for both y-axes
ax9.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
ax10.ticklabel_format(axis='y', style='sci', scilimits=(0,0))


# Place 1e at the top of the axis
ax9.yaxis.get_offset_text().set_position((0, 1))
ax10.yaxis.get_offset_text().set_position((1, 1))

ax9.tick_params(axis='both', which='major', labelsize=36)
ax10.tick_params(axis='both', which='major', labelsize=36)

ax9.yaxis.offsetText.set_fontsize(36)  # 调整上标1e的大小
ax10.yaxis.offsetText.set_fontsize(36)  # 调整上标1e的大小

ax9.set_ylim(0, 6000)

ax11=plt.subplot(2, 4, 6)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)    

B=ax11.plot(iteration,accumulative_constraint_violation_small_IOS_online_algorithm,color = 'green',linewidth = '3',label='proposed+IOS')
C=ax11.plot(iteration,accumulative_constraint_violation_small_TM_online_algorithm,color = 'blue',linewidth = '3',label='proposed+TM')
D=ax11.plot(iteration,accumulative_constraint_violation_small_SCC_online_algorithm,color = 'red',linewidth = '3',label='proposed+SCC')

ax12 = ax11.twinx()
A=ax12.plot(iteration,accumulative_constraint_violation_small_online_algorithm,color = 'dimgrey',linewidth = '3',label='attack-free')
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=36)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 36,
}
ax11.set_xlabel('T', fontsize=49)
#ax3.set_ylabel('Dynamic regret', fontsize=18)
#ax2.set_ylabel('Dynamic regret', fontsize=18)
#plt.title('small-value',font2)

# Set scientific notation for both y-axes
ax11.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
ax12.ticklabel_format(axis='y', style='sci', scilimits=(0,0))

# Place 1e at the top of the axis
ax11.yaxis.get_offset_text().set_position((0, 1))
ax12.yaxis.get_offset_text().set_position((1, 1))

ax11.tick_params(axis='both', which='major', labelsize=36)
ax12.tick_params(axis='both', which='major', labelsize=36)

ax11.yaxis.offsetText.set_fontsize(36)  # 调整上标1e的大小
ax12.yaxis.offsetText.set_fontsize(36)  # 调整上标1e的大小

ax11.set_ylim(0, 6000)

ax13=plt.subplot(2, 4, 7)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

B=ax13.plot(iteration,accumulative_constraint_violation_large_Gaussian_IOS_online_algorithm,color = 'green',linewidth = '3',label='proposed+IOS')
C=ax13.plot(iteration,accumulative_constraint_violation_large_Gaussian_TM_online_algorithm,color = 'blue',linewidth = '3',label='proposed+TM')
D=ax13.plot(iteration,accumulative_constraint_violation_large_Gaussian_SCC_online_algorithm,color = 'red',linewidth = '3',label='proposed+SCC')

ax14 = ax13.twinx()
A=ax14.plot(iteration,accumulative_constraint_violation_large_Gaussian_online_algorithm,color = 'dimgrey',linewidth = '3',label='attack-free')

#设置图例并且设置图例的字体及大小
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=36)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 36,
}
ax13.set_xlabel('T', fontsize=49)
#ax3.set_ylabel('Dynamic regret', fontsize=18)
#ax2.set_ylabel('Dynamic regret', fontsize=18)
#plt.title('large-value Gaussian',font2)

# Set scientific notation for both y-axes
ax13.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
ax14.ticklabel_format(axis='y', style='sci', scilimits=(0,0))

# Place 1e at the top of the axis
ax13.yaxis.get_offset_text().set_position((0, 1))
ax14.yaxis.get_offset_text().set_position((1, 1))

ax13.tick_params(axis='both', which='major', labelsize=36)
ax14.tick_params(axis='both', which='major', labelsize=36)

ax13.yaxis.offsetText.set_fontsize(36)  # 调整上标1e的大小
ax14.yaxis.offsetText.set_fontsize(36)  # 调整上标1e的大小

ax13.set_ylim(0, 6000)

ax15=plt.subplot(2, 4, 8)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

B=ax15.plot(iteration,accumulative_constraint_violation_small_Gaussian_IOS_online_algorithm,color = 'green',linewidth = '3',label='proposed+IOS')
C=ax15.plot(iteration,accumulative_constraint_violation_small_Gaussian_TM_online_algorithm,color = 'blue',linewidth = '3',label='proposed+TM')
D=ax15.plot(iteration,accumulative_constraint_violation_small_Gaussian_SCC_online_algorithm,color = 'red',linewidth = '3',label='proposed+SCC')

ax16 = ax15.twinx()
A=ax16.plot(iteration,accumulative_constraint_violation_small_Gaussian_online_algorithm,color = 'dimgrey',linewidth = '3',label='attack-free')
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=36)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 36,
}
ax15.set_xlabel('T', fontsize=49)
#ax3.set_ylabel('Dynamic regret', fontsize=18)
#ax2.set_ylabel('Dynamic regret', fontsize=18)
#plt.title('small-value Gaussian',font2)

# Set scientific notation for both y-axes
ax15.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
ax16.ticklabel_format(axis='y', style='sci', scilimits=(0,0))

# Place 1e at the top of the axis
ax15.yaxis.get_offset_text().set_position((0, 1))
ax16.yaxis.get_offset_text().set_position((1, 1))

ax15.tick_params(axis='both', which='major', labelsize=36)
ax16.tick_params(axis='both', which='major', labelsize=36)

ax15.yaxis.offsetText.set_fontsize(36)  # 调整上标1e的大小
ax16.yaxis.offsetText.set_fontsize(36)  # 调整上标1e的大小

ax15.set_ylim(0, 6000)

ax1.set_xticklabels([])
ax3.set_xticklabels([])
ax5.set_xticklabels([])
ax7.set_xticklabels([])

# Set legend for both axes
plt.legend(lines, labels, loc="upper center", bbox_to_anchor=[-1.36, -0.2], ncol=28, shadow=True, fancybox=True, prop={'size': 49})

plt.subplots_adjust(wspace=0.25,hspace=0.08) 
plt.gcf().set_size_inches((38, 16))

plt.savefig('./figures/03-figure3_dynamic_regret_accumulative_constraint_violations.pdf',format='pdf', bbox_inches='tight')
plt.savefig('./figures/03-figure3_dynamic_regret_accumulative_constraint_violations.png',format='png', bbox_inches='tight')
